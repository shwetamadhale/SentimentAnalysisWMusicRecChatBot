# %%
# !pip install anvil-uplink
# Out:
# Collecting anvil-uplink
#   Using cached anvil_uplink-0.3.40-py2.py3-none-any.whl (62 kB)
# Collecting ws4py
#   Using cached ws4py-0.5.1.tar.gz (51 kB)
# Requirement already satisfied: six in c:\users\madha\anaconda3\lib\site-packages (from anvil-uplink) (1.15.0)
# Requirement already satisfied: future in c:\users\madha\anaconda3\lib\site-packages (from anvil-uplink) (0.18.2)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: ws4py
#   Building wheel for ws4py (setup.py): started
#   Building wheel for ws4py (setup.py): finished with status 'done'
#   Created wheel for ws4py: filename=ws4py-0.5.1-py3-none-any.whl size=45215 sha256=0699bebb36a2247c9f450fef38662c714690625f3deacad3251f27cd089c12fa
#   Stored in directory: c:\users\madha\appdata\local\pip\cache\wheels\ea\f9\a1\34e2943cce3cf7daca304bfc35e91280694ced9194a487ce2f
# Successfully built ws4py
# Installing collected packages: ws4py, argparse, anvil-uplink
# Successfully installed anvil-uplink-0.3.40 argparse-1.4.0 ws4py-0.5.1

# %%
import anvil.server

anvil.server.connect("HU7U5DEGSJCT4NX4CNMXKXZO-4RBTIA7COKKOFH52")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment (dev)" as SERVER

# %%
import numpy as np

# %%
import tensorflow as tf

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense, Activation, Dropout

# %%
#optimizers
from tensorflow.keras.optimizers import SGD

# %%
import random

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
import json
import pickle

# %%
intents_file = open('C:/Users/madha/Downloads/Chatbot using Sentiment Analysis for song recommendation/intents.json').read()
intents = json.loads(intents_file)

# %%
#tokenization and corpus
import nltk
nltk.download('punkt')
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenizing each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #corpus
        documents.append((word, intent['tag']))
        #list classes
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\madha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['whats', 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['how', 'old', 'are', 'you'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'sky_net_yes'), (['Yeah'], 'sky_net_yes'), (['Haha', 'yep'], 'sky_net_yes'), (['yes'], 'sky_net_yes'), (['Indeed'], 'sky_net_yes'), (['Yup'], 'sky_net_yes'), (['Just', 'like', 'the', 'terminator'], 'sky_net_yes'), (['no'], 'sky_net_no'), (['nah'], 'sky_net_no'), (['not', 'really'], 'sky_net_no'), (['thats', 'scary'], 'sky_net_no'), (['singularity'], 'sky_net_no'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['you', 'real'], 'real_bot'), (['you', 'human'], 'real_bot'), (['you', 'robot'], 'real_bot'), (['you', 'alive'], 'real_bot'), (['you', 'sentient'], 'real_bot'), (['you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['haha'], 'good_joke'), (['that', 'was', 'funny'], 'good_joke'), (['very', 'funny'], 'good_joke'), (['good', 'one'], 'good_joke'), (['bad', 'joke'], 'bad_joke'), (['trash', 'joke'], 'bad_joke'), (['terrible'], 'bad_joke'), (['not', 'funny'], 'bad_joke'), (['I', 'hate', 'you'], 'hate'), (['you', 'stupid'], 'hate'), (['you', 'dumb'], 'hate'), (['you', 'mean'], 'hate'), (['you', 'my', 'friend'], 'like'), (['I', 'like', 'you'], 'like'), (['I', 'love', 'you'], 'like'), (['you', 'cool'], 'like'), (['you', 'are', 'chill'], 'like'), (['whats', 'favorite', 'show'], 'favorite_show'), (['favorite', 'tv', 'show'], 'favorite_show'), (['Whats', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'film'], 'favorite_movie'), (['best', 'movie'], 'favorite_movie'), (['your', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'movie'], 'favorite_movie'), (['What', 'think', 'about'], 'your_thoughts'), (['What', 'your', 'thoughts'], 'your_thoughts')]

# %%
#wordnet dictionary
import nltk
nltk.download('wordnet')
#training
training = []
#output
output_empty = [0] * len(classes)
#training and bagging sentence
for doc in documents:
    #initialization
    bag = []
    
    #list of tokenized words
    word_patterns = doc[0]
    
    #word root lemmatize
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    
    #bagging for matches
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    #0 op for each tag and 1 for currebt tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
    
random.shuffle(training)
training = np.array(training)

#training and testing
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data successful")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\madha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# Training data successful
# <ipython-input-16-00e0abc0e9e8>:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
#NN Model

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

#Compiling, SGD and Nesterov accelerated gradient
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model is created")
# Out:
# Epoch 1/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3.1248 - accuracy: 0.0202
# Epoch 2/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9155 - accuracy: 0.1414
# Epoch 3/200
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8030 - accuracy: 0.1717
# Epoch 4/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.7018 - accuracy: 0.1919
# Epoch 5/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5940 - accuracy: 0.2121
# Epoch 6/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4770 - accuracy: 0.2121
# Epoch 7/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4071 - accuracy: 0.2929
# Epoch 8/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.2920 - accuracy: 0.2929
# Epoch 9/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.2611 - accuracy: 0.3131
# Epoch 10/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.1303 - accuracy: 0.3232
# Epoch 11/200
# 20/20 [==============================] - 0s 898us/step - loss: 2.0149 - accuracy: 0.3939
# Epoch 12/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0701 - accuracy: 0.3131
# Epoch 13/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8352 - accuracy: 0.3838
# Epoch 14/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1.8738 - accuracy: 0.3535
# Epoch 15/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7800 - accuracy: 0.4949
# Epoch 16/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8800 - accuracy: 0.3434
# Epoch 17/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6237 - accuracy: 0.5253
# Epoch 18/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6665 - accuracy: 0.4242
# Epoch 19/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6833 - accuracy: 0.5152
# Epoch 20/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5337 - accuracy: 0.5152
# Epoch 21/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5014 - accuracy: 0.4949
# Epoch 22/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5486 - accuracy: 0.5152
# Epoch 23/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5153 - accuracy: 0.5455
# Epoch 24/200
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5293 - accuracy: 0.4747
# Epoch 25/200
# 20/20 [==============================] - 0s 6ms/step - loss: 1.2856 - accuracy: 0.6162
# Epoch 26/200
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3427 - accuracy: 0.5455
# Epoch 27/200
# 20/20 [==============================] - 0s 5ms/step - loss: 1.2128 - accuracy: 0.5556
# Epoch 28/200
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2014 - accuracy: 0.5556
# Epoch 29/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.5960
# Epoch 30/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2305 - accuracy: 0.5657
# Epoch 31/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1885 - accuracy: 0.6667
# Epoch 32/200
# 20/20 [==============================] - 0s 996us/step - loss: 0.9637 - accuracy: 0.7273
# Epoch 33/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0813 - accuracy: 0.6465
# Epoch 34/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.2507 - accuracy: 0.5657
# Epoch 35/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9759 - accuracy: 0.7374
# Epoch 36/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9501 - accuracy: 0.6768
# Epoch 37/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0236 - accuracy: 0.6364
# Epoch 38/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7516 - accuracy: 0.7576
# Epoch 39/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9417 - accuracy: 0.6970
# Epoch 40/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.8978 - accuracy: 0.6768
# Epoch 41/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9531 - accuracy: 0.6364
# Epoch 42/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7885 - accuracy: 0.7879
# Epoch 43/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9098 - accuracy: 0.6667
# Epoch 44/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8321 - accuracy: 0.7374
# Epoch 45/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9011 - accuracy: 0.6667
# Epoch 46/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8314 - accuracy: 0.7475
# Epoch 47/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8736 - accuracy: 0.6970
# Epoch 48/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9942 - accuracy: 0.6970
# Epoch 49/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8907 - accuracy: 0.7273
# Epoch 50/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7944 - accuracy: 0.7071
# Epoch 51/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.7410 - accuracy: 0.7576
# Epoch 52/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7430 - accuracy: 0.7576
# Epoch 53/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7937 - accuracy: 0.7273
# Epoch 54/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6686 - accuracy: 0.7475
# Epoch 55/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7725 - accuracy: 0.7576
# Epoch 56/200
# 20/20 [==============================] - 0s 396us/step - loss: 0.6740 - accuracy: 0.7778
# Epoch 57/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6051 - accuracy: 0.7980
# Epoch 58/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.7374
# Epoch 59/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7020 - accuracy: 0.7576
# Epoch 60/200
# 20/20 [==============================] - 0s 648us/step - loss: 0.9026 - accuracy: 0.7071
# Epoch 61/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6697 - accuracy: 0.7677
# Epoch 62/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6933 - accuracy: 0.7576
# Epoch 63/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.7778
# Epoch 64/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6901 - accuracy: 0.8182
# Epoch 65/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.7558 - accuracy: 0.7273
# Epoch 66/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7193 - accuracy: 0.7576
# Epoch 67/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6635 - accuracy: 0.7576
# Epoch 68/200
# 20/20 [==============================] - 0s 798us/step - loss: 0.6517 - accuracy: 0.7879
# Epoch 69/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.7164 - accuracy: 0.7576
# Epoch 70/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6473 - accuracy: 0.7778
# Epoch 71/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5436 - accuracy: 0.8384
# Epoch 72/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6890 - accuracy: 0.7475
# Epoch 73/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6212 - accuracy: 0.7677
# Epoch 74/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5270 - accuracy: 0.8283
# Epoch 75/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.8485
# Epoch 76/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6259 - accuracy: 0.7980
# Epoch 77/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6567 - accuracy: 0.7475
# Epoch 78/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6016 - accuracy: 0.7576
# Epoch 79/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.7677
# Epoch 80/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6473 - accuracy: 0.7677
# Epoch 81/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6422 - accuracy: 0.7576
# Epoch 82/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6455 - accuracy: 0.7879
# Epoch 83/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6385 - accuracy: 0.7879
# Epoch 84/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.7273
# Epoch 85/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6276 - accuracy: 0.7677
# Epoch 86/200
# 20/20 [==============================] - 0s 997us/step - loss: 0.5737 - accuracy: 0.7879
# Epoch 87/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5876 - accuracy: 0.7475
# Epoch 88/200
# 20/20 [==============================] - 0s 898us/step - loss: 0.6619 - accuracy: 0.7374
# Epoch 89/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5429 - accuracy: 0.8081
# Epoch 90/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6247 - accuracy: 0.8081
# Epoch 91/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6777 - accuracy: 0.7475
# Epoch 92/200
# 20/20 [==============================] - 0s 798us/step - loss: 0.5865 - accuracy: 0.7677
# Epoch 93/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5065 - accuracy: 0.8485
# Epoch 94/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5459 - accuracy: 0.8182
# Epoch 95/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.8081
# Epoch 96/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5436 - accuracy: 0.8081
# Epoch 97/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6110 - accuracy: 0.7677
# Epoch 98/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5119 - accuracy: 0.7879
# Epoch 99/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7967 - accuracy: 0.6970
# Epoch 100/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7351 - accuracy: 0.7475
# Epoch 101/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5761 - accuracy: 0.7677
# Epoch 102/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6762 - accuracy: 0.7980
# Epoch 103/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.7054 - accuracy: 0.7778
# Epoch 104/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5636 - accuracy: 0.8384
# Epoch 105/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5694 - accuracy: 0.7778
# Epoch 106/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5730 - accuracy: 0.8081
# Epoch 107/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6953 - accuracy: 0.7576
# Epoch 108/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5702 - accuracy: 0.8384
# Epoch 109/200
# 20/20 [==============================] - 0s 748us/step - loss: 0.5376 - accuracy: 0.7980
# Epoch 110/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.8081
# Epoch 111/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5183 - accuracy: 0.8384
# Epoch 112/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5615 - accuracy: 0.7980
# Epoch 113/200
# 20/20 [==============================] - 0s 846us/step - loss: 0.6004 - accuracy: 0.7576
# Epoch 114/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.7576
# Epoch 115/200
# 20/20 [==============================] - 0s 879us/step - loss: 0.5875 - accuracy: 0.7879
# Epoch 116/200
# 20/20 [==============================] - 0s 896us/step - loss: 0.6891 - accuracy: 0.7273
# Epoch 117/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.7374
# Epoch 118/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6173 - accuracy: 0.7980
# Epoch 119/200
# 20/20 [==============================] - 0s 997us/step - loss: 0.4982 - accuracy: 0.8182
# Epoch 120/200
# 20/20 [==============================] - 0s 945us/step - loss: 0.5505 - accuracy: 0.7475
# Epoch 121/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5472 - accuracy: 0.7879
# Epoch 122/200
# 20/20 [==============================] - 0s 749us/step - loss: 0.5414 - accuracy: 0.7677
# Epoch 123/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5933 - accuracy: 0.7879
# Epoch 124/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5507 - accuracy: 0.7980
# Epoch 125/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.8384
# Epoch 126/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.8384
# Epoch 127/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6044 - accuracy: 0.7879
# Epoch 128/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5508 - accuracy: 0.8081
# Epoch 129/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 0.7879
# Epoch 130/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4938 - accuracy: 0.7980
# Epoch 131/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5772 - accuracy: 0.7980
# Epoch 132/200
# 20/20 [==============================] - 0s 798us/step - loss: 0.5455 - accuracy: 0.7778
# Epoch 133/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6360 - accuracy: 0.7677
# Epoch 134/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4628 - accuracy: 0.8182
# Epoch 135/200
# 20/20 [==============================] - 0s 798us/step - loss: 0.5194 - accuracy: 0.7879
# Epoch 136/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4710 - accuracy: 0.8687
# Epoch 137/200
# 20/20 [==============================] - 0s 748us/step - loss: 0.5541 - accuracy: 0.7778
# Epoch 138/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5153 - accuracy: 0.7980
# Epoch 139/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.7778
# Epoch 140/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.8081
# Epoch 141/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6088 - accuracy: 0.7778
# Epoch 142/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.8384
# Epoch 143/200
# 20/20 [==============================] - 0s 798us/step - loss: 0.4804 - accuracy: 0.8283
# Epoch 144/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4134 - accuracy: 0.8788
# Epoch 145/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4565 - accuracy: 0.8586
# Epoch 146/200
# 20/20 [==============================] - 0s 847us/step - loss: 0.5294 - accuracy: 0.8081
# Epoch 147/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4620 - accuracy: 0.8283
# Epoch 148/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5165 - accuracy: 0.8081
# Epoch 149/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6070 - accuracy: 0.7576
# Epoch 150/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.7879
# Epoch 151/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4837 - accuracy: 0.8182
# Epoch 152/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4663 - accuracy: 0.8081
# Epoch 153/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4921 - accuracy: 0.8182
# Epoch 154/200
# 20/20 [==============================] - 0s 947us/step - loss: 0.4661 - accuracy: 0.7778
# Epoch 155/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4878 - accuracy: 0.8687
# Epoch 156/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.7879
# Epoch 157/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4707 - accuracy: 0.8081
# Epoch 158/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4826 - accuracy: 0.7980
# Epoch 159/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4589 - accuracy: 0.8182
# Epoch 160/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4634 - accuracy: 0.7677
# Epoch 161/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4664 - accuracy: 0.7980
# Epoch 162/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5984 - accuracy: 0.7475
# Epoch 163/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4745 - accuracy: 0.8586
# Epoch 164/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8788
# Epoch 165/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.8182
# Epoch 166/200
# 20/20 [==============================] - 0s 848us/step - loss: 0.4861 - accuracy: 0.8485
# Epoch 167/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.8485
# Epoch 168/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.8182
# Epoch 169/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5512 - accuracy: 0.7879
# Epoch 170/200
# 20/20 [==============================] - 0s 897us/step - loss: 0.5268 - accuracy: 0.7879
# Epoch 171/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4475 - accuracy: 0.7980
# Epoch 172/200
# 20/20 [==============================] - 0s 948us/step - loss: 0.4111 - accuracy: 0.8182
# Epoch 173/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4311 - accuracy: 0.8586
# Epoch 174/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4621 - accuracy: 0.8081
# Epoch 175/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5928 - accuracy: 0.7778
# Epoch 176/200
# 20/20 [==============================] - 0s 748us/step - loss: 0.4929 - accuracy: 0.8182
# Epoch 177/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4697 - accuracy: 0.8182
# Epoch 178/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.8283
# Epoch 179/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5316 - accuracy: 0.8081
# Epoch 180/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5011 - accuracy: 0.7980
# Epoch 181/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4325 - accuracy: 0.8182
# Epoch 182/200
# 20/20 [==============================] - 0s 948us/step - loss: 0.4956 - accuracy: 0.8485
# Epoch 183/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.8182
# Epoch 184/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5138 - accuracy: 0.7879
# Epoch 185/200
# 20/20 [==============================] - 0s 804us/step - loss: 0.4137 - accuracy: 0.7980
# Epoch 186/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4936 - accuracy: 0.8283
# Epoch 187/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4117 - accuracy: 0.8384
# Epoch 188/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8485
# Epoch 189/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.8384
# Epoch 190/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.8081
# Epoch 191/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3666 - accuracy: 0.8485
# Epoch 192/200
# 20/20 [==============================] - 0s 897us/step - loss: 0.3723 - accuracy: 0.8586
# Epoch 193/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3744 - accuracy: 0.8586
# Epoch 194/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.8384
# Epoch 195/200
# 20/20 [==============================] - 0s 951us/step - loss: 0.3663 - accuracy: 0.8687
# Epoch 196/200
# 20/20 [==============================] - 0s 789us/step - loss: 0.5198 - accuracy: 0.8182
# Epoch 197/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4328 - accuracy: 0.8384
# Epoch 198/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7778
# Epoch 199/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4160 - accuracy: 0.8283
# Epoch 200/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8081
# model is created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('C:/Users/madha/Downloads/Chatbot using Sentiment Analysis for song recommendation/intents.json').read())
words = pickle.load(open('C:/Users/madha/Downloads/Chatbot using Sentiment Analysis for song recommendation/words.pkl','rb'))
classes = pickle.load(open('C:/Users/madha/Downloads/Chatbot using Sentiment Analysis for song recommendation/classes.pkl','rb'))
def clean_up_sentence(sentence):
    #tokenizing
    sentence_words = nltk.word_tokenize(sentence)
    #stemming to root
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
#BOG array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    #tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    #bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    #filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
intents_file = open('C:/Users/madha/Downloads/Chatbot using Sentiment Analysis for song recommendation/intents.json').read()
intents = json.loads(intents_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenizing
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #corpus
        documents.append((word, intent['tag']))
        #classes
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
#rooting and redundancy rmoval
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))

#sorting
classes = sorted(list(set(classes)))

#documents = combination between patterns and intents
print (len(documents), "documents")

#classes = intents
print (len(classes), "classes", classes)

#words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

#Training data
training = []
#output
output_empty = [0] * len(classes)

#training set and BOG Sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=172, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['whats', 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['how', 'old', 'are', 'you'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'sky_net_yes'), (['Yeah'], 'sky_net_yes'), (['Haha', 'yep'], 'sky_net_yes'), (['yes'], 'sky_net_yes'), (['Indeed'], 'sky_net_yes'), (['Yup'], 'sky_net_yes'), (['Just', 'like', 'the', 'terminator'], 'sky_net_yes'), (['no'], 'sky_net_no'), (['nah'], 'sky_net_no'), (['not', 'really'], 'sky_net_no'), (['thats', 'scary'], 'sky_net_no'), (['singularity'], 'sky_net_no'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['you', 'real'], 'real_bot'), (['you', 'human'], 'real_bot'), (['you', 'robot'], 'real_bot'), (['you', 'alive'], 'real_bot'), (['you', 'sentient'], 'real_bot'), (['you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['haha'], 'good_joke'), (['that', 'was', 'funny'], 'good_joke'), (['very', 'funny'], 'good_joke'), (['good', 'one'], 'good_joke'), (['bad', 'joke'], 'bad_joke'), (['trash', 'joke'], 'bad_joke'), (['terrible'], 'bad_joke'), (['not', 'funny'], 'bad_joke'), (['I', 'hate', 'you'], 'hate'), (['you', 'stupid'], 'hate'), (['you', 'dumb'], 'hate'), (['you', 'mean'], 'hate'), (['you', 'my', 'friend'], 'like'), (['I', 'like', 'you'], 'like'), (['I', 'love', 'you'], 'like'), (['you', 'cool'], 'like'), (['you', 'are', 'chill'], 'like'), (['whats', 'favorite', 'show'], 'favorite_show'), (['favorite', 'tv', 'show'], 'favorite_show'), (['Whats', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'film'], 'favorite_movie'), (['best', 'movie'], 'favorite_movie'), (['your', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'movie'], 'favorite_movie'), (['What', 'think', 'about'], 'your_thoughts'), (['What', 'your', 'thoughts'], 'your_thoughts')]
# 99 documents
# 21 classes ['age', 'bad_joke', 'doing_badly', 'doing_great', 'favorite_movie', 'favorite_show', 'good_joke', 'goodbye', 'greeting', 'hate', 'how_are_you', 'joke', 'like', 'name', 'netflix', 'quick_run', 'real_bot', 'sky_net_no', 'sky_net_yes', 'thanks', 'your_thoughts']
# 113 unique lemmatized words ['a', 'about', 'address', 'age', 'alive', 'am', 'any', 'anyone', 'are', 'awesome', 'awful', 'bad', 'badly', 'best', 'better', 'bye', 'call', 'can', 'chill', 'conscious', 'cool', 'cya', 'day', 'do', 'doe', 'doing', 'dumb', 'favorite', 'film', 'friend', 'funny', 'going', 'good', 'goodbye', 'got', 'great', 'haha', 'happy', 'hate', 'have', 'hello', 'hey', 'hi', 'horrible', 'how', 'human', 'i', 'im', 'indeed', 'is', 'it', 'joke', 'just', 'later', 'leaving', 'like', 'love', 'me', 'mean', 'movie', 'my', 'nah', 'name', 'netflix', 'no', 'not', 'old', 'on', 'one', 'owe', 'real', 'really', 'robot', 'run', 'sad', 'scary', 'see', 'sentient', 'should', 'show', 'singularity', 'stupid', 'sup', 'tell', 'terminator', 'terrible', 'thank', 'thanks', 'thankyou', 'that', 'thats', 'the', 'there', 'think', 'thought', 'trash', 'tv', 'ty', 'up', 'very', 'wa', 'wait', 'watch', 'well', 'what', 'whats', 'why', 'yeah', 'yep', 'yes', 'you', 'your', 'yup']
# Training data created
# Epoch 1/172
# <ipython-input-19-80546ea2e6e3>:73: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# 20/20 [==============================] - 0s 1ms/step - loss: 3.0334 - accuracy: 0.1111
# Epoch 2/172
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0074 - accuracy: 0.0808
# Epoch 3/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9515 - accuracy: 0.0909
# Epoch 4/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8965 - accuracy: 0.1919
# Epoch 5/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8351 - accuracy: 0.2222
# Epoch 6/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.7745 - accuracy: 0.2222
# Epoch 7/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.6978 - accuracy: 0.1919
# Epoch 8/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5681 - accuracy: 0.2929
# Epoch 9/172
# 20/20 [==============================] - 0s 1ms/step - loss: 2.4207 - accuracy: 0.3636
# Epoch 10/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.3905 - accuracy: 0.3535
# Epoch 11/172
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1525 - accuracy: 0.3535
# Epoch 12/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.1529 - accuracy: 0.3737
# Epoch 13/172
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0974 - accuracy: 0.4444
# Epoch 14/172
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9719 - accuracy: 0.3737
# Epoch 15/172
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8791 - accuracy: 0.4343
# Epoch 16/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7172 - accuracy: 0.5051
# Epoch 17/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7506 - accuracy: 0.4949
# Epoch 18/172
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5491 - accuracy: 0.5253
# Epoch 19/172
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5141 - accuracy: 0.5455
# Epoch 20/172
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4300 - accuracy: 0.5859
# Epoch 21/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2556 - accuracy: 0.6869
# Epoch 22/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2105 - accuracy: 0.6566
# Epoch 23/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3332 - accuracy: 0.5960
# Epoch 24/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1823 - accuracy: 0.6768
# Epoch 25/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9742 - accuracy: 0.7273
# Epoch 26/172
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0650 - accuracy: 0.6970
# Epoch 27/172
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1280 - accuracy: 0.6465
# Epoch 28/172
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9598 - accuracy: 0.7273
# Epoch 29/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9531 - accuracy: 0.7475
# Epoch 30/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.8230 - accuracy: 0.7677
# Epoch 31/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8428 - accuracy: 0.7576
# Epoch 32/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7104 - accuracy: 0.7879
# Epoch 33/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6554 - accuracy: 0.7980
# Epoch 34/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.7426 - accuracy: 0.7677
# Epoch 35/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7502 - accuracy: 0.7778
# Epoch 36/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.8990
# Epoch 37/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5357 - accuracy: 0.8081
# Epoch 38/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.8384
# Epoch 39/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5660 - accuracy: 0.7879
# Epoch 40/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6081 - accuracy: 0.8283
# Epoch 41/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.8586
# Epoch 42/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.8889
# Epoch 43/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8990
# Epoch 44/172
# 20/20 [==============================] - 0s 997us/step - loss: 0.5148 - accuracy: 0.8384
# Epoch 45/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8990
# Epoch 46/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4340 - accuracy: 0.8687
# Epoch 47/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.8586
# Epoch 48/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.8889
# Epoch 49/172
# 20/20 [==============================] - 0s 947us/step - loss: 0.4263 - accuracy: 0.8889
# Epoch 50/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.8586
# Epoch 51/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.8990
# Epoch 52/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3944 - accuracy: 0.8788
# Epoch 53/172
# 20/20 [==============================] - 0s 848us/step - loss: 0.2402 - accuracy: 0.9394
# Epoch 54/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.9091
# Epoch 55/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2673 - accuracy: 0.9192
# Epoch 56/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3195 - accuracy: 0.8990
# Epoch 57/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.9091
# Epoch 58/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2755 - accuracy: 0.9293
# Epoch 59/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8586
# Epoch 60/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8990
# Epoch 61/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9596
# Epoch 62/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2597 - accuracy: 0.9293
# Epoch 63/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2002 - accuracy: 0.9495
# Epoch 64/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2776 - accuracy: 0.8990
# Epoch 65/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2341 - accuracy: 0.9293
# Epoch 66/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3085 - accuracy: 0.8889
# Epoch 67/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.9495
# Epoch 68/172
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3435 - accuracy: 0.8889
# Epoch 69/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.8889
# Epoch 70/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2020 - accuracy: 0.9192
# Epoch 71/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2536 - accuracy: 0.9495
# Epoch 72/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.8990
# Epoch 73/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2371 - accuracy: 0.9293
# Epoch 74/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.9091
# Epoch 75/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2715 - accuracy: 0.9192
# Epoch 76/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3232 - accuracy: 0.8990
# Epoch 77/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2166 - accuracy: 0.9091
# Epoch 78/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1932 - accuracy: 0.9293
# Epoch 79/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1448 - accuracy: 0.9899
# Epoch 80/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2150 - accuracy: 0.9394
# Epoch 81/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1580 - accuracy: 0.9798
# Epoch 82/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1969 - accuracy: 0.8990
# Epoch 83/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1324 - accuracy: 0.9899
# Epoch 84/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9394
# Epoch 85/172
# 20/20 [==============================] - 0s 997us/step - loss: 0.1591 - accuracy: 0.9394
# Epoch 86/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2184 - accuracy: 0.9293
# Epoch 87/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1412 - accuracy: 0.9697
# Epoch 88/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 0.9697
# Epoch 89/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1839 - accuracy: 0.9293
# Epoch 90/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9596
# Epoch 91/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9293
# Epoch 92/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2211 - accuracy: 0.9293
# Epoch 93/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1994 - accuracy: 0.9293
# Epoch 94/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9394
# Epoch 95/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.9697
# Epoch 96/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.9495
# Epoch 97/172
# 20/20 [==============================] - 0s 997us/step - loss: 0.1448 - accuracy: 0.9697
# Epoch 98/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.9798
# Epoch 99/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9798
# Epoch 100/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9192
# Epoch 101/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9596
# Epoch 102/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9394
# Epoch 103/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1292 - accuracy: 0.9697
# Epoch 104/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9495
# Epoch 105/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9192
# Epoch 106/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1813 - accuracy: 0.9697
# Epoch 107/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1478 - accuracy: 0.9596
# Epoch 108/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1675 - accuracy: 0.9596
# Epoch 109/172
# 20/20 [==============================] - 0s 996us/step - loss: 0.1407 - accuracy: 0.9596
# Epoch 110/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1381 - accuracy: 0.9596
# Epoch 111/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1371 - accuracy: 0.9495
# Epoch 112/172
# 20/20 [==============================] - 0s 948us/step - loss: 0.1186 - accuracy: 0.9798
# Epoch 113/172
# 20/20 [==============================] - 0s 798us/step - loss: 0.1724 - accuracy: 0.9394
# Epoch 114/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1528 - accuracy: 0.9495
# Epoch 115/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1443 - accuracy: 0.9596
# Epoch 116/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9192
# Epoch 117/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9495
# Epoch 118/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9697
# Epoch 119/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1322 - accuracy: 0.9697
# Epoch 120/172
# 20/20 [==============================] - 0s 997us/step - loss: 0.1238 - accuracy: 0.9596
# Epoch 121/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1581 - accuracy: 0.9394
# Epoch 122/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9596
# Epoch 123/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9899
# Epoch 124/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.9697
# Epoch 125/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1251 - accuracy: 0.9495
# Epoch 126/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9899
# Epoch 127/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1287 - accuracy: 0.9596
# Epoch 128/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0594 - accuracy: 0.9899
# Epoch 129/172
# 20/20 [==============================] - 0s 998us/step - loss: 0.2200 - accuracy: 0.8990
# Epoch 130/172
# 20/20 [==============================] - 0s 648us/step - loss: 0.1362 - accuracy: 0.9596
# Epoch 131/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9394
# Epoch 132/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1487 - accuracy: 0.9495
# Epoch 133/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 0.9899
# Epoch 134/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9596
# Epoch 135/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1171 - accuracy: 0.9697
# Epoch 136/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.9798
# Epoch 137/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0837 - accuracy: 0.9899
# Epoch 138/172
# 20/20 [==============================] - 0s 997us/step - loss: 0.1061 - accuracy: 0.9596
# Epoch 139/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 0.9596
# Epoch 140/172
# 20/20 [==============================] - 0s 998us/step - loss: 0.1725 - accuracy: 0.9394
# Epoch 141/172
# 20/20 [==============================] - 0s 798us/step - loss: 0.1183 - accuracy: 0.9596
# Epoch 142/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 0.9596
# Epoch 143/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.9798
# Epoch 144/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1126 - accuracy: 0.9596
# Epoch 145/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1076 - accuracy: 0.9596
# Epoch 146/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0619 - accuracy: 0.9899
# Epoch 147/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0883 - accuracy: 0.9697
# Epoch 148/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1205 - accuracy: 0.9596
# Epoch 149/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9495
# Epoch 150/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.9394
# Epoch 151/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1877 - accuracy: 0.9293
# Epoch 152/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9798
# Epoch 153/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9798
# Epoch 154/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 155/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 1.0000
# Epoch 156/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9596
# Epoch 157/172
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1327 - accuracy: 0.9697
# Epoch 158/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9495
# Epoch 159/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9596
# Epoch 160/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9596
# Epoch 161/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9697
# Epoch 162/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9697
# Epoch 163/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9697
# Epoch 164/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.9697
# Epoch 165/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9596
# Epoch 166/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0728 - accuracy: 0.9798
# Epoch 167/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.9596
# Epoch 168/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9798
# Epoch 169/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9798
# Epoch 170/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9798
# Epoch 171/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9798
# Epoch 172/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9798
# model created

# %%
import json
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-c1dd3269ad46> in <module>
#       1 import json
# ----> 2 from ibm_watson import ToneAnalyzerV3
#       3 from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
#
# ModuleNotFoundError: No module named 'ibm_watson'

# %%
pip install --upgrade "ibm-watson>=5.3.0"
# Out:
# Collecting ibm-watson>=5.3.0
#   Downloading ibm-watson-5.3.0.tar.gz (412 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6
#   Downloading ibm-cloud-sdk-core-3.11.3.tar.gz (45 kB)
# Requirement already satisfied: requests<3.0,>=2.0 in c:\users\madha\anaconda3\lib\site-packages (from ibm-watson>=5.3.0) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\madha\anaconda3\lib\site-packages (from ibm-watson>=5.3.0) (2.8.1)
# Collecting websocket-client==1.1.0
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.1 in c:\users\madha\anaconda3\lib\site-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm-watson>=5.3.0) (2.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\madha\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->ibm-watson>=5.3.0) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\madha\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\madha\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.0) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\madha\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madha\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.0) (2020.12.5)
# Building wheels for collected packages: ibm-watson, ibm-cloud-sdk-core
#   Building wheel for ibm-watson (PEP 517): started
#   Building wheel for ibm-watson (PEP 517): finished with status 'done'
#   Created wheel for ibm-watson: filename=ibm_watson-5.3.0-py3-none-any.whl size=408872 sha256=c4a2565226f9eb2d556b65f3ae7924e65c3c7c3117efedb85a92f828ff6c6ed9
#   Stored in directory: c:\users\madha\appdata\local\pip\cache\wheels\79\7c\1e\3fc8483af029cd8cb8c803eeaf282cbeb60724130d9dca4b83
#   Building wheel for ibm-cloud-sdk-core (setup.py): started
#   Building wheel for ibm-cloud-sdk-core (setup.py): finished with status 'done'
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.11.3-py3-none-any.whl size=74742 sha256=2b7122125da97ce23249ca2613711e913f8e3887920847b1920e2a941b9692d3
#   Stored in directory: c:\users\madha\appdata\local\pip\cache\wheels\df\d0\62\8e04dea28cc4684de1793bd2e14c46a0fd3b422c5fc35d59aa
# Successfully built ibm-watson ibm-cloud-sdk-core
# Installing collected packages: websocket-client, ibm-cloud-sdk-core, ibm-watson
# Successfully installed ibm-cloud-sdk-core-3.11.3 ibm-watson-5.3.0 websocket-client-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
msg = list()
text = str()

# %%
@anvil.server.callable
def responsed(msg1):
    msg.append(msg1)
    ints = predict_class(msg1)
    res = getResponse(ints, intents)
    return res

# %%
@anvil.server.callable
def song_emotion():
    authenticator = IAMAuthenticator("acgtQdBTLh1ul15KYi-6bfbP5EGtSC1OVrM6wgLooiLp")
    tone_analyzer = ToneAnalyzerV3(
        version='2017-09-21',
        authenticator=authenticator
    
    )

    tone_analyzer.set_service_url( "https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/77cd4a81-e420-4212-85bc-3f4c4ae6dd4a")
    # text = ""
    # for i in msg:
    #     text = text+i
    len1 = len(msg)
    tone_analysis = tone_analyzer.tone(
        {'text': msg[len1-1]+" "+msg[len1-2]+" "+msg[len1-3]+" "+msg[len1-4]+" "+msg[len1-5]},
        content_type='application/json'
    ).get_result()
    dic1 = dict()
    emotion=tone_analysis["document_tone"]["tones"][0]["tone_name"]
    dic1['emotion'] = emotion
    import requests

    url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={emotion}&api_key=dc767f78f7b91f7b55d01c13fb684e31&format=json&limit=10"
    response = requests.get(url)
    payload = response.json()
    for i in range(10):
        r=payload['tracks']['track'][i]
        dic1[r['name']] = r['url']
    return dic1

# %%
import requests

url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag=happy&api_key=dc767f78f7b91f7b55d01c13fb684e31&format=json&limit=5"
response = requests.get(url)
payload = response.json()
# for i in range(4):
r=payload['tracks']['track'][0]
# print(r['url'])
print(payload)

# %%
print("Chatbot : Hey there, Wassup ?")
# responded function takes text of user and returns chatbot output
for i in range(5):
    m = input("User : ")
    res = responsed(m)
    print("Chatbot : "+res)
ans = song_emotion()
print("Emotion : "+ans['emotion'])

# %%
ans = song_emotion()
print("Emotion : "+ans['emotion'])
ans.pop('emotion')
lst = list(ans.keys())
print("Song Recommendations : ")
for i in range(10):
    print("Song_name : "+lst[i])
    print("Song_URL : "+ans[lst[i]])
